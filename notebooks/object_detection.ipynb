# %% [markdown]
# # Object detection
# In this notebook you will learn how to do object detection with VisionPipeline library.

# %%
# Set up modules directory to import the library
import sys
import os
sys.path.append(os.path.abspath(os.path.join('..', 'src')))

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np
from visionpipelines.constants import DetectionMethod
from visionpipelines.pipelines.object_detection_pipeline import ObjectDetectionPipeline

# %%
# read test image
image_path1 = '../tests/data/people_image.webp'
image1 = cv2.imread(image_path1)

# %%
imgplot1 = plt.imshow(cv2.cvtColor(image1, cv2.COLOR_BGR2RGB))

# %%
# Use FASTER RCNN method for object detection
pipeline = ObjectDetectionPipeline(DetectionMethod.FASTER_RCNN)

# Perform object detection
boxes, labels, scores = pipeline.run_pipeline(image1)


image_with_boxes = pipeline.draw_boxes(image1, boxes, labels, scores)

# %%
# display detected objects
plt.imshow(cv2.cvtColor(image_with_boxes, cv2.COLOR_BGR2RGB))
